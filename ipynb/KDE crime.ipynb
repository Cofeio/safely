# %%
import pandas as pd

# %%
df = pd.read_csv('./data/sf_crime.csv')
df = df[pd.notnull(df['Latitude'])]
df = df[pd.notnull(df['Longitude'])]
df = df[:20000]

# %%
from scipy.stats.kde import gaussian_kde
import numpy as np

# %%
plt.scatter(df['Longitude'],df['Latitude'])

# %%
x = df['Longitude']
y =  df['Latitude']
k = gaussian_kde(np.vstack([x, y]), bw_method='silverman')
xi, yi = np.mgrid[x.min():x.max():x.size**0.5*1j,y.min():y.max():y.size**0.5*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))
a = plt.contour(xi, yi, zi.reshape(xi.shape), alpha=0.5)

# %%
contour_index = len(a.collections)//2
p = a.collections[0].get_paths()[0]
v = p.vertices
x = v[:,0]
y = v[:,1]
plt.scatter(x,y)

# %%
median(zi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-190-0b41c7f2664e> in <module>()
#       1
# ----> 2 median(zi)
#
# NameError: name 'median' is not defined

# %%
# Make the plot
plt.pcolormesh(xi, yi, normalized.reshape(xi.shape))
plt.show()

# %%
37//2
# Out:
# 18

# %%
path = a.collections[0].get_paths()

# %%
p0 = path[0]
p0
# Out:
# Path(array([[-122.51129493,   37.7088914 ],
#        [-122.51129493,   37.70976262],
#        [-122.51129493,   37.71063384],
#        ...,
#        [-122.43687241,   37.77946009],
#        [-122.43670719,   37.77858887],
#        [-122.4364649 ,   37.77787543]]), array([ 1,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
# ...

# %%
p0._vertices
# Out:
# array([[-122.51129493,   37.7088914 ],
#        [-122.51129493,   37.70976262],
#        [-122.51129493,   37.71063384],
#        ...,
#        [-122.43687241,   37.77946009],
#        [-122.43670719,   37.77858887],
#        [-122.4364649 ,   37.77787543]])

# %%
p00  = p0.vertices
p00
# Out:
# array([[-122.51129493,   37.7088914 ],
#        [-122.51129493,   37.70976262],
#        [-122.51129493,   37.71063384],
#        ...,
#        [-122.43687241,   37.77946009],
#        [-122.43670719,   37.77858887],
#        [-122.4364649 ,   37.77787543]])

# %%
p_list = p00.tolist()
p_list

# %%
p = a.collections[0].get_paths()[0]
v = p.vertices
x = v[:,0]
y = v[:,1]
plt.scatter(x,y)

# %%
x,y = zip(*p_list)[0], zip(*p_list)[1]
plt.scatter(x,y)

# %%
import PIL.ImageDraw as ImageDraw
import PIL.Image as Image

image = Image.new("RGB", (640, 480))

draw = ImageDraw.Draw(image)

# points = ((1,1), (2,1), (2,2), (1,2), (0.5,1.5))
points = p0.to_polygons()[0]
draw.polygon((points), fill=1)

image.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,8))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

# alpha=0.5 will make the plots semitransparent
ax1.pcolormesh(xi, yi, zi.reshape(xi.shape), alpha=0.5)
ax2.contourf(xi, yi, zi.reshape(xi.shape), alpha=0.5)

ax1.set_xlim(x.min(), x.max())
ax1.set_ylim(y.min(), y.max())
ax2.set_xlim(x.min(), x.max())
ax2.set_ylim(y.min(), y.max())

# you can also overlay your soccer field
# im = plt.imread('soccerPitch.jpg')
ax1.show(extent=[x.min(), x.max(), y.min(), y.max()], aspect='auto')
ax2.show(extent=[x.min(), x.max(), y.min(), y.max()], aspect='auto')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-6317d89d831f> in <module>()
#      16 # you can also overlay your soccer field
#      17 # im = plt.imread('soccerPitch.jpg')
# ---> 18 ax1.show(extent=[x.min(), x.max(), y.min(), y.max()], aspect='auto')
#      19 ax2.show(extent=[x.min(), x.max(), y.min(), y.max()], aspect='auto')
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'
